# %% [markdown]
# # Scatterplot change in prediction model parallelism score (PS) over training
# Generate scatterplots of prediction model parallelism score $\text{PS}\left(h^{\text{final}}_{\text{prediction}_i} \circ h_{\text{entangler}}(\mathbf{X}_i)\right)$ after final training epoch vs. during initial training epoch $\text{PS}\left(h^{\text{random}}_{\text{prediction}_i} \circ h_{\text{entangler}}(\mathbf{X}_i)\right)$.

# %% [markdown]
# ##### Import statements:

# %%
import os
import pathlib
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
from matplotlib import colormaps
from analysis_metadata.analysis_metadata import Metadata, increment_dir_name, write_metadata

# %% [markdown]
# ##### Define inputs, parameters:

# %%
# Input file:
input_path = os.path.join('/', 'mnt', 'smb', 'locker', 'issa-locker', 'users', 'Dan', 'code', 'ws', 'results', 'run845', 'tngl_pred.pickle')
input_dir = os.path.split(input_path)[0]

# Output parameters:
save_output = True
base_dir_name = 'ps_post_v_ps_pre'

# %% [markdown]
# ##### Load previously-saved results:

# %%
tngl_evo_pred_results = pickle.load(open(input_path, 'rb'))
geo_df = tngl_evo_pred_results['geo_df'] 
loss_df = tngl_evo_pred_results['ae_df']

# %% [markdown]
# ##### Select results for prediction model, hidden layer:

# %%
geo_df_pred = geo_df[geo_df.mdl_type=='prediction']
geo_df_pred_hidden = geo_df_pred[geo_df_pred.layer=='hidden']

# %% [markdown]
# ##### For each model, find results for first and last epochs, merge:

# %%
# Get first epoch results:
geo_df_pred_hidden_e0 = geo_df_pred_hidden[geo_df_pred_hidden.epoch==0]
geo_df_pred_hidden_e0 = geo_df_pred_hidden_e0.rename(columns={'parallelism':'parallelism_e0'}) 

# Get final epoch results:
max_epoch_df = geo_df_pred_hidden[['pred_mdl_id', 'epoch']].groupby('pred_mdl_id').max().reset_index()
geo_df_pred_hidden_efinal = pd.merge(geo_df_pred_hidden, max_epoch_df, on=['pred_mdl_id', 'epoch'])
geo_df_pred_hidden_efinal = geo_df_pred_hidden_efinal.rename(columns={'parallelism':'parallelism_efinal'}) 

# Merge on model id:
ps_history_df = pd.merge(geo_df_pred_hidden_e0[['pred_mdl_id', 'dichotomy_idx', 'train_partition_inds', 'parallelism_e0']],\
      geo_df_pred_hidden_efinal[['pred_mdl_id', 'dichotomy_idx', 'train_partition_inds','parallelism_efinal']],\
      on=['pred_mdl_id', 'dichotomy_idx', 'train_partition_inds'])

# %% [markdown]
# ##### Compute mean initial and final hidden-layer PS for each model:

# %%
scatter_df = ps_history_df.groupby(['pred_mdl_id', 'dichotomy_idx']).mean()\
    .groupby('pred_mdl_id').mean().reset_index()

# %% [markdown]
# ##### Scatter prediction model hidden layer final epoch parallelism $\text{PS}(h^{\text{final}}_{\text{prediction}_i} \circ h_{\text{entangler}}(\mathbf{X}_i))$ vs prediction model hidden layer first epoch parallelism  $\text{PS}(h^{\text{random}}_{\text{prediction}_i} \circ h_{\text{entangler}}(\mathbf{X}_i))$:

# %%
scatter_fig, scatter_ax = plt.subplots()

leg_text = r'$n_{{\text{{prediction model realizations}}}} = {}$'.format(scatter_df.shape[0])
plt.scatter(scatter_df.parallelism_e0, scatter_df.parallelism_efinal, label=leg_text)

# Set axes equal:
yl = plt.ylim()
xl = plt.xlim()
minmin = np.min([xl[0], yl[0]])
maxmax = np.max([xl[1], yl[1]])
plt.xlim([minmin, maxmax])
plt.ylim([minmin, maxmax])
scatter_ax.set_aspect('equal')

# Add unity line:
plt.axline([0,0], slope=1, color='gray', linewidth=1, linestyle='--')

# Add lines for means along each dimension:
plt.vlines(scatter_df.parallelism_e0.mean(), 0, 1, color='black', linewidth=1)
plt.hlines(scatter_df.parallelism_efinal.mean(), 0, 1, color='black', linewidth=1)

# Add axis labels:
xlabel = r'$\text{PS}\left(h^{\text{random}}_{\text{prediction}_i} \circ h_{\text{entangler}}(\mathbf{X}_i)\right)$'
ylabel = r'$\text{PS}\left(h^{\text{final}}_{\text{prediction}_i} \circ h_{\text{entangler}}(\mathbf{X}_i)\right)$'
plt.xlabel(xlabel)
plt.ylabel(ylabel)

# Add title:
title = '\n'.join(['Final prediction model PS', 'vs', 'initial prediction model PS'])
plt.title(title)

# Add legend:
plt.legend()

# %% [markdown]
# ##### Save output:

# %%
if save_output:

    # Create output directory:
    input_dir = os.path.split(input_path)[0]
    base_dir_name = 'scatter_ps_post_v_ps_pre'
    curr_output_directory = increment_dir_name(input_dir, base_dir_name)
    if not os.path.exists(curr_output_directory):
        pathlib.Path(curr_output_directory).mkdir(parents=True,exist_ok=True)

    # Save figures:
    plt.figure(scatter_fig)
    file_basename = 'scatter_ps_post_v_ps_pre'
    ps_png_path = os.path.join(curr_output_directory, file_basename+'.png')
    plt.savefig(ps_png_path)
    ps_svg_path =  os.path.join(curr_output_directory, file_basename+'.svg')
    plt.savefig(ps_svg_path)
    
    # Define metadata:
    M = Metadata()
    M.add_input(input_path)
    M.add_output(ps_png_path)
    M.add_output(ps_svg_path)
    metadata_path = os.path.join(curr_output_directory, 'scatter_ps_post_v_ps_pre.json')
    write_metadata(M, metadata_path)
# Out:
# Computing checksum for /mnt/smb/locker/issa-locker/users/Dan/code/ws/results/run845/tngl_pred.pickle...
# Computing checksum for /mnt/smb/locker/issa-locker/users/Dan/code/ws/results/run845/scatter_ps_post_v_ps_pre002/scatter_ps_post_v_ps_pre.png...
# Computing checksum for /mnt/smb/locker/issa-locker/users/Dan/code/ws/results/run845/scatter_ps_post_v_ps_pre002/scatter_ps_post_v_ps_pre.svg...
